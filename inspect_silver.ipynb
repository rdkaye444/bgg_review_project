# %%
import pandas as pd

df = pd.read_csv('data/silver_enriched.csv', sep=',')
df.columns
# Out:
# Index(['Unnamed: 0', 'id', 'name', 'year_published', 'min_players',
#        'max_players', 'play_time', 'min_age', 'users_rated', 'rating_average',
#        'bgg_rank', 'complexity_average', 'owned_users', 'mechanics', 'domains',
#        'mechanics_list', 'description'],
#       dtype='object')

# %%
df.head()
# Out:
#    Unnamed: 0      id                               name  year_published  \
# 0           0  174430                         Gloomhaven            2017
# 1           1  161936          Pandemic Legacy: Season 1            2015
# 2           2  224517                  Brass: Birmingham            2018
# 3           3  167791                  Terraforming Mars            2016
# 4           4  233078  Twilight Imperium: Fourth Edition            2017
#
#    min_players  max_players  play_time  min_age  users_rated  rating_average  \
# 0            1            4        120       14        42055            8.79
# 1            2            4         60       13        41643            8.61
# 2            2            4        120       14        19217            8.66
# 3            1            5        120       12        64864            8.43
# 4            3            6        480       14        13468            8.70
#
#    bgg_rank  complexity_average  owned_users  \
# ...

# %%
df_2020 = df_2020.sort_values("rating_average", ascending=False)
top_15_2020 = df_2020.head(15)
bottom_15_2020 = df_2020.tail(15)
combined_2020 = pd.concat([top_15_2020, bottom_15_2020])

# %%
combined_2020.to_csv("data/combined_2020.csv")

# %%
combined_2020.head()
# Out:
#        Unnamed: 0      id                                        name  \
# 13540       13547  281257                                      Aeolis
# 11477       11480  281515                           Company of Heroes
# 12240       12244  273814                                 Deliverance
# 12139       12143  293981  The Adventure Zone: Bureau of Balance Game
# 14536       14545  260037                                 Composition
#
#        year_published  min_players  max_players  play_time  min_age  \
# 13540            2020            1            7        120       18
# 11477            2020            2            4         90       12
# 12240            2020            1            4        120       13
# 12139            2020            2            5         90       12
# 14536            2020            2            5         60        8
#
#        users_rated  rating_average  bgg_rank  complexity_average  owned_users  \
# ...
